# %%
from keras.layers import Activation
from keras.layers import Add
from keras.layers import AveragePooling2D
from keras.layers import BatchNormalization
from keras.layers import Concatenate
from keras.layers import Conv2D
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import GlobalMaxPooling2D
from keras.layers import Input
from keras.layers import Lambda
from keras.layers import MaxPooling2D
from keras.layers import ZeroPadding2D
from keras.models import Model
from keras.optimizers import Adam
from keras.initializers import glorot_uniform
from keras.callbacks import LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.utils import to_categorical
from keras.datasets import cifar10
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
batch_size = 32
epochs = 200
input_shape = (32, 32, 3)
num_classes = 10

# %%
# Loading and preprocessing the data
def load_data():
    (x_train, y_train), (x_test, y_test) = cifar10.load_data()
    
    # Normalize data.
    x_train = x_train.astype('float32') / 255.0
    x_test = x_test.astype('float32') / 255.0

    # subtract pixel mean
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

    # Convert class vectors to binary class matrices.
    y_train = to_categorical(y_train, num_classes)
    y_test = to_categorical(y_test, num_classes)
    
    return (x_train, x_test), (y_train, y_test)

# %%
(x_train, x_test), (y_train, y_test) = load_data()

# %%
def lr_schedule(epoch):
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    return lr

# %%
# Splits the input data into groups. Number of groups determined by cardinality. Cardinality = 4 in this implementation
def split(inputs, cardinality):
    inputs_channels = inputs.shape[3]
    group_size = inputs_channels // cardinality    
    groups = list()
    for number in range(1, cardinality+1):
        begin = int((number-1)*group_size)
        end = int(number*group_size)
        block = Lambda(lambda x:x[:,:,:,begin:end])(inputs)
        groups.append(block)
    return groups

# %%
# Forward propogation and concatenating of the groups
def transform(groups, filters, strides, stage, block):
    f1, f2 = filters    
    conv_name = "conv2d-{stage}{block}-branch".format(stage=str(stage), block=str(block))
    bn_name = "batchnorm-{stage}{block}-branch".format(stage=str(stage), block=str(block))
    
    transformed_tensor = list()
    i = 1
    
    for inputs in groups:
        # first conv of the transformation phase
        x = Conv2D(filters=f1, kernel_size=(1,1), strides=strides, padding="valid", 
                   name=conv_name+'1a_split'+str(i), kernel_initializer=glorot_uniform(seed=0))(inputs)
        x = BatchNormalization(axis=3, name=bn_name+'1a_split'+str(i))(x)
        x = Activation('relu')(x)

        # second conv of the transformation phase
        x = Conv2D(filters=f2, kernel_size=(3,3), strides=(1,1), padding="same", 
                   name=conv_name+'1b_split'+str(i), kernel_initializer=glorot_uniform(seed=0))(x)
        x = BatchNormalization(axis=3, name=bn_name+'1b_split'+str(i))(x)
        x = Activation('relu')(x)
        
        # Add x to transformed tensor list
        transformed_tensor.append(x)
        i+=1
        
    # Concatenate all tensor from each group
    x = Concatenate(name='concat'+str(stage)+''+block)(transformed_tensor)
    
    return x

# %%
# Transition block
def transition(inputs, filters, stage, block):
    x = Conv2D(filters=filters, kernel_size=(1,1), strides=(1,1), padding="valid", 
                   name='conv2d-trans'+str(stage)+''+block, kernel_initializer=glorot_uniform(seed=0))(inputs)
    x = BatchNormalization(axis=3, name='batchnorm-trans'+str(stage)+''+block)(x)
    x = Activation('relu')(x)
    
    return x

# %%
# Identity block
def identity_block(inputs, filters, cardinality, stage, block, strides=(1,1)):
    
    conv_name = "conv2d-{stage}{block}-branch".format(stage=str(stage),block=str(block))
    bn_name = "batchnorm-{stage}{block}-branch".format(stage=str(stage),block=str(block))
    
    #save the input tensor value
    x_shortcut = inputs
    x = inputs
    
    f1, f2, f3 = filters
    
    # divide input channels into groups. The number of groups is define by cardinality param
    groups = split(inputs=x, cardinality=cardinality)
    
    # transform each group by doing a set of convolutions and concat the results
    f1 = int(f1 / cardinality)
    f2 = int(f2 / cardinality)
    x = transform(groups=groups, filters=(f1, f2), strides=strides, stage=stage, block=block)
    
    # make a transition by doing 1x1 conv
    x = transition(inputs=x, filters=f3, stage=stage, block=block)
    
    # Last step of the identity block, shortcut concatenation
    x = Add()([x,x_shortcut])
    x = Activation('relu')(x)
    
    return x

# %%
# Residual connection block
def downsampling(inputs, filters, cardinality, strides, stage, block):
    
    # useful variables
    conv_name = "conv2d-{stage}{block}-branch".format(stage=str(stage), block=str(block))
    bn_name = "batchnorm-{stage}{block}-branch".format(stage=str(stage), block=str(block))
    
    # Retrieve filters for each layer
    f1, f2, f3 = filters
    
    # save the input tensor value
    x_shortcut = inputs
    x = inputs
    
    # divide input channels into groups. The number of groups is define by cardinality param
    groups = split(inputs=x, cardinality=cardinality)
    
    # transform each group by doing a set of convolutions and concat the results
    f1 = int(f1 / cardinality)
    f2 = int(f2 / cardinality)
    x = transform(groups=groups, filters=(f1, f2), strides=strides, stage=stage, block=block)
    
    # make a transition by doing 1x1 conv
    x = transition(inputs=x, filters=f3, stage=stage, block=block)
    
    # Projection Shortcut to match dimensions 
    x_shortcut = Conv2D(filters=f3, kernel_size=(1,1), strides=strides, padding="valid", 
               name='{base}2'.format(base=conv_name), kernel_initializer=glorot_uniform(seed=0))(x_shortcut)
    x_shortcut = BatchNormalization(axis=3, name='{base}2'.format(base=bn_name))(x_shortcut)
    
    # Add x and x_shortcut
    x = Add()([x,x_shortcut])
    x = Activation('relu')(x)
    
    return x

# %%
def ResNeXt50(input_shape, classes):
    
    # Transform input to a tensor of shape input_shape 
    x_input = Input(input_shape)
    
    # Add zero padding
    x = ZeroPadding2D((3,3))(x_input)
    
    # Initial Stage. Let's say stage 1
    x = Conv2D(filters=64, kernel_size=(7,7), strides=(2,2), 
               name='conv2d_1', kernel_initializer=glorot_uniform(seed=0))(x)
    x = BatchNormalization(axis=3, name='batchnorm_1')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((3,3), strides=(2,2))(x)
    
    # Stage 2
    x = downsampling(inputs=x, filters=(128,128,256), cardinality=4, strides=(2,2), stage=2, block="a")
    x = identity_block(inputs=x, filters=(128,128,256), cardinality=4, stage=2, block="b")
    x = identity_block(inputs=x, filters=(128,128,256), cardinality=4, stage=2, block="c")
    
    
    # Stage 3
    x = downsampling(inputs=x, filters=(256,256,512), cardinality=4, strides=(2,2), stage=3, block="a")
    x = identity_block(inputs=x, filters=(256,256,512), cardinality=4, stage=3, block="b")
    x = identity_block(inputs=x, filters=(256,256,512), cardinality=4, stage=3, block="c")
    x = identity_block(inputs=x, filters=(256,256,512), cardinality=4, stage=3, block="d")
    
    
    # Stage 4
    x = downsampling(inputs=x, filters=(512,512,1024), cardinality=4, strides=(2,2), stage=4, block="a")
    x = identity_block(inputs=x, filters=(512,512,1024), cardinality=4, stage=4, block="b")
    x = identity_block(inputs=x, filters=(512,512,1024), cardinality=4, stage=4, block="c")
    x = identity_block(inputs=x, filters=(512,512,1024), cardinality=4, stage=4, block="d")
    x = identity_block(inputs=x, filters=(512,512,1024), cardinality=4, stage=4, block="e")
    x = identity_block(inputs=x, filters=(512,512,1024), cardinality=4, stage=4, block="f")
    
    
    # Stage 5
    x = downsampling(inputs=x, filters=(1024,1024,2048), cardinality=4, strides=(2,2), stage=5, block="a")
    x = identity_block(inputs=x, filters=(1024,1024,2048), cardinality=4, stage=5, block="b")
    x = identity_block(inputs=x, filters=(1024,1024,2048), cardinality=4, stage=5, block="c")
    
    
    # Average pooling
    x = AveragePooling2D(pool_size=(2,2), padding="same")(x)
    
    # Output layer
    x = Flatten()(x)
    x = Dense(classes, activation="softmax", kernel_initializer=glorot_uniform(seed=0), 
              name="fc{cls}".format(cls=str(classes)))(x)
    
    # Create the model
    model = Model(inputs=x_input, outputs=x, name="resnet50")
    
    return model

# %%
# Building the model
model = ResNeXt50(input_shape=(224,224,3), classes=2)

# Callbacks
lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1), cooldown=0, patiente=5, min_lr=0.5e-6)
lr_scheduler = LearningRateScheduler(lr_schedule)

callbacks = [lr_reducer, lr_scheduler]

model.compile(optimizer=Adam(lr=lr_schedule(0)), loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, 230, 230, 3)  0           input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 112, 112, 64) 9472        zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# batchnorm_1 (BatchNormalization (None, 112, 112, 64) 256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_162 (Activation)     (None, 112, 112, 64) 0           batchnorm_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 55, 55, 64)   0           activation_162[0][0]
# __________________________________________________________________________________________________
# lambda_65 (Lambda)              (None, 55, 55, 16)   0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# lambda_66 (Lambda)              (None, 55, 55, 16)   0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# lambda_67 (Lambda)              (None, 55, 55, 16)   0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# lambda_68 (Lambda)              (None, 55, 55, 16)   0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d-2a-branch1a_split1 (Conv (None, 28, 28, 32)   544         lambda_65[0][0]
# __________________________________________________________________________________________________
# conv2d-2a-branch1a_split2 (Conv (None, 28, 28, 32)   544         lambda_66[0][0]
# __________________________________________________________________________________________________
# conv2d-2a-branch1a_split3 (Conv (None, 28, 28, 32)   544         lambda_67[0][0]
# __________________________________________________________________________________________________
# conv2d-2a-branch1a_split4 (Conv (None, 28, 28, 32)   544         lambda_68[0][0]
# __________________________________________________________________________________________________
# batchnorm-2a-branch1a_split1 (B (None, 28, 28, 32)   128         conv2d-2a-branch1a_split1[0][0]
# __________________________________________________________________________________________________
# batchnorm-2a-branch1a_split2 (B (None, 28, 28, 32)   128         conv2d-2a-branch1a_split2[0][0]
# __________________________________________________________________________________________________
# batchnorm-2a-branch1a_split3 (B (None, 28, 28, 32)   128         conv2d-2a-branch1a_split3[0][0]
# __________________________________________________________________________________________________
# batchnorm-2a-branch1a_split4 (B (None, 28, 28, 32)   128         conv2d-2a-branch1a_split4[0][0]
# __________________________________________________________________________________________________
# activation_163 (Activation)     (None, 28, 28, 32)   0           batchnorm-2a-branch1a_split1[0][0
# __________________________________________________________________________________________________
# activation_165 (Activation)     (None, 28, 28, 32)   0           batchnorm-2a-branch1a_split2[0][0
# __________________________________________________________________________________________________
# activation_167 (Activation)     (None, 28, 28, 32)   0           batchnorm-2a-branch1a_split3[0][0
# __________________________________________________________________________________________________
# activation_169 (Activation)     (None, 28, 28, 32)   0           batchnorm-2a-branch1a_split4[0][0
# __________________________________________________________________________________________________
# conv2d-2a-branch1b_split1 (Conv (None, 28, 28, 32)   9248        activation_163[0][0]
# __________________________________________________________________________________________________
# conv2d-2a-branch1b_split2 (Conv (None, 28, 28, 32)   9248        activation_165[0][0]
# __________________________________________________________________________________________________
# conv2d-2a-branch1b_split3 (Conv (None, 28, 28, 32)   9248        activation_167[0][0]
# __________________________________________________________________________________________________
# conv2d-2a-branch1b_split4 (Conv (None, 28, 28, 32)   9248        activation_169[0][0]
# __________________________________________________________________________________________________
# batchnorm-2a-branch1b_split1 (B (None, 28, 28, 32)   128         conv2d-2a-branch1b_split1[0][0]
# __________________________________________________________________________________________________
# batchnorm-2a-branch1b_split2 (B (None, 28, 28, 32)   128         conv2d-2a-branch1b_split2[0][0]
# __________________________________________________________________________________________________
# batchnorm-2a-branch1b_split3 (B (None, 28, 28, 32)   128         conv2d-2a-branch1b_split3[0][0]
# __________________________________________________________________________________________________
# batchnorm-2a-branch1b_split4 (B (None, 28, 28, 32)   128         conv2d-2a-branch1b_split4[0][0]
# __________________________________________________________________________________________________
# activation_164 (Activation)     (None, 28, 28, 32)   0           batchnorm-2a-branch1b_split1[0][0
# __________________________________________________________________________________________________
# activation_166 (Activation)     (None, 28, 28, 32)   0           batchnorm-2a-branch1b_split2[0][0
# __________________________________________________________________________________________________
# activation_168 (Activation)     (None, 28, 28, 32)   0           batchnorm-2a-branch1b_split3[0][0
# __________________________________________________________________________________________________
# activation_170 (Activation)     (None, 28, 28, 32)   0           batchnorm-2a-branch1b_split4[0][0
# __________________________________________________________________________________________________
# concat2a (Concatenate)          (None, 28, 28, 128)  0           activation_164[0][0]
#                                                                  activation_166[0][0]
#                                                                  activation_168[0][0]
#                                                                  activation_170[0][0]
# __________________________________________________________________________________________________
# conv2d-trans2a (Conv2D)         (None, 28, 28, 256)  33024       concat2a[0][0]
# __________________________________________________________________________________________________
# batchnorm-trans2a (BatchNormali (None, 28, 28, 256)  1024        conv2d-trans2a[0][0]
# __________________________________________________________________________________________________
# conv2d-2a-branch2 (Conv2D)      (None, 28, 28, 256)  16640       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# activation_171 (Activation)     (None, 28, 28, 256)  0           batchnorm-trans2a[0][0]
# __________________________________________________________________________________________________
# batchnorm-2a-branch2 (BatchNorm (None, 28, 28, 256)  1024        conv2d-2a-branch2[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 28, 28, 256)  0           activation_171[0][0]
#                                                                  batchnorm-2a-branch2[0][0]
# __________________________________________________________________________________________________
# activation_172 (Activation)     (None, 28, 28, 256)  0           add_17[0][0]
# __________________________________________________________________________________________________
# lambda_69 (Lambda)              (None, 28, 28, 64)   0           activation_172[0][0]
# __________________________________________________________________________________________________
# lambda_70 (Lambda)              (None, 28, 28, 64)   0           activation_172[0][0]
# __________________________________________________________________________________________________
# lambda_71 (Lambda)              (None, 28, 28, 64)   0           activation_172[0][0]
# __________________________________________________________________________________________________
# lambda_72 (Lambda)              (None, 28, 28, 64)   0           activation_172[0][0]
# __________________________________________________________________________________________________
# conv2d-2b-branch1a_split1 (Conv (None, 28, 28, 32)   2080        lambda_69[0][0]
# __________________________________________________________________________________________________
# conv2d-2b-branch1a_split2 (Conv (None, 28, 28, 32)   2080        lambda_70[0][0]
# __________________________________________________________________________________________________
# conv2d-2b-branch1a_split3 (Conv (None, 28, 28, 32)   2080        lambda_71[0][0]
# __________________________________________________________________________________________________
# conv2d-2b-branch1a_split4 (Conv (None, 28, 28, 32)   2080        lambda_72[0][0]
# __________________________________________________________________________________________________
# batchnorm-2b-branch1a_split1 (B (None, 28, 28, 32)   128         conv2d-2b-branch1a_split1[0][0]
# __________________________________________________________________________________________________
# batchnorm-2b-branch1a_split2 (B (None, 28, 28, 32)   128         conv2d-2b-branch1a_split2[0][0]
# __________________________________________________________________________________________________
# batchnorm-2b-branch1a_split3 (B (None, 28, 28, 32)   128         conv2d-2b-branch1a_split3[0][0]
# __________________________________________________________________________________________________
# batchnorm-2b-branch1a_split4 (B (None, 28, 28, 32)   128         conv2d-2b-branch1a_split4[0][0]
# __________________________________________________________________________________________________
# activation_173 (Activation)     (None, 28, 28, 32)   0           batchnorm-2b-branch1a_split1[0][0
# __________________________________________________________________________________________________
# activation_175 (Activation)     (None, 28, 28, 32)   0           batchnorm-2b-branch1a_split2[0][0
# __________________________________________________________________________________________________
# activation_177 (Activation)     (None, 28, 28, 32)   0           batchnorm-2b-branch1a_split3[0][0
# __________________________________________________________________________________________________
# activation_179 (Activation)     (None, 28, 28, 32)   0           batchnorm-2b-branch1a_split4[0][0
# __________________________________________________________________________________________________
# conv2d-2b-branch1b_split1 (Conv (None, 28, 28, 32)   9248        activation_173[0][0]
# __________________________________________________________________________________________________
# conv2d-2b-branch1b_split2 (Conv (None, 28, 28, 32)   9248        activation_175[0][0]
# __________________________________________________________________________________________________
# conv2d-2b-branch1b_split3 (Conv (None, 28, 28, 32)   9248        activation_177[0][0]
# __________________________________________________________________________________________________
# conv2d-2b-branch1b_split4 (Conv (None, 28, 28, 32)   9248        activation_179[0][0]
# __________________________________________________________________________________________________
# batchnorm-2b-branch1b_split1 (B (None, 28, 28, 32)   128         conv2d-2b-branch1b_split1[0][0]
# __________________________________________________________________________________________________
# batchnorm-2b-branch1b_split2 (B (None, 28, 28, 32)   128         conv2d-2b-branch1b_split2[0][0]
# __________________________________________________________________________________________________
# batchnorm-2b-branch1b_split3 (B (None, 28, 28, 32)   128         conv2d-2b-branch1b_split3[0][0]
# __________________________________________________________________________________________________
# batchnorm-2b-branch1b_split4 (B (None, 28, 28, 32)   128         conv2d-2b-branch1b_split4[0][0]
# __________________________________________________________________________________________________
# activation_174 (Activation)     (None, 28, 28, 32)   0           batchnorm-2b-branch1b_split1[0][0
# __________________________________________________________________________________________________
# activation_176 (Activation)     (None, 28, 28, 32)   0           batchnorm-2b-branch1b_split2[0][0
# __________________________________________________________________________________________________
# activation_178 (Activation)     (None, 28, 28, 32)   0           batchnorm-2b-branch1b_split3[0][0
# __________________________________________________________________________________________________
# activation_180 (Activation)     (None, 28, 28, 32)   0           batchnorm-2b-branch1b_split4[0][0
# __________________________________________________________________________________________________
# concat2b (Concatenate)          (None, 28, 28, 128)  0           activation_174[0][0]
#                                                                  activation_176[0][0]
#                                                                  activation_178[0][0]
#                                                                  activation_180[0][0]
# __________________________________________________________________________________________________
# conv2d-trans2b (Conv2D)         (None, 28, 28, 256)  33024       concat2b[0][0]
# __________________________________________________________________________________________________
# batchnorm-trans2b (BatchNormali (None, 28, 28, 256)  1024        conv2d-trans2b[0][0]
# __________________________________________________________________________________________________
# activation_181 (Activation)     (None, 28, 28, 256)  0           batchnorm-trans2b[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 28, 28, 256)  0           activation_181[0][0]
#                                                                  activation_172[0][0]
# __________________________________________________________________________________________________
# activation_182 (Activation)     (None, 28, 28, 256)  0           add_18[0][0]
# __________________________________________________________________________________________________
# lambda_73 (Lambda)              (None, 28, 28, 64)   0           activation_182[0][0]
# __________________________________________________________________________________________________
# lambda_74 (Lambda)              (None, 28, 28, 64)   0           activation_182[0][0]
# __________________________________________________________________________________________________
# lambda_75 (Lambda)              (None, 28, 28, 64)   0           activation_182[0][0]
# __________________________________________________________________________________________________
# lambda_76 (Lambda)              (None, 28, 28, 64)   0           activation_182[0][0]
# __________________________________________________________________________________________________
# conv2d-2c-branch1a_split1 (Conv (None, 28, 28, 32)   2080        lambda_73[0][0]
# __________________________________________________________________________________________________
# conv2d-2c-branch1a_split2 (Conv (None, 28, 28, 32)   2080        lambda_74[0][0]
# __________________________________________________________________________________________________
# conv2d-2c-branch1a_split3 (Conv (None, 28, 28, 32)   2080        lambda_75[0][0]
# __________________________________________________________________________________________________
# conv2d-2c-branch1a_split4 (Conv (None, 28, 28, 32)   2080        lambda_76[0][0]
# __________________________________________________________________________________________________
# batchnorm-2c-branch1a_split1 (B (None, 28, 28, 32)   128         conv2d-2c-branch1a_split1[0][0]
# __________________________________________________________________________________________________
# batchnorm-2c-branch1a_split2 (B (None, 28, 28, 32)   128         conv2d-2c-branch1a_split2[0][0]
# __________________________________________________________________________________________________
# batchnorm-2c-branch1a_split3 (B (None, 28, 28, 32)   128         conv2d-2c-branch1a_split3[0][0]
# __________________________________________________________________________________________________
# batchnorm-2c-branch1a_split4 (B (None, 28, 28, 32)   128         conv2d-2c-branch1a_split4[0][0]
# __________________________________________________________________________________________________
# activation_183 (Activation)     (None, 28, 28, 32)   0           batchnorm-2c-branch1a_split1[0][0
# __________________________________________________________________________________________________
# activation_185 (Activation)     (None, 28, 28, 32)   0           batchnorm-2c-branch1a_split2[0][0
# __________________________________________________________________________________________________
# activation_187 (Activation)     (None, 28, 28, 32)   0           batchnorm-2c-branch1a_split3[0][0
# __________________________________________________________________________________________________
# activation_189 (Activation)     (None, 28, 28, 32)   0           batchnorm-2c-branch1a_split4[0][0
# __________________________________________________________________________________________________
# conv2d-2c-branch1b_split1 (Conv (None, 28, 28, 32)   9248        activation_183[0][0]
# __________________________________________________________________________________________________
# conv2d-2c-branch1b_split2 (Conv (None, 28, 28, 32)   9248        activation_185[0][0]
# __________________________________________________________________________________________________
# conv2d-2c-branch1b_split3 (Conv (None, 28, 28, 32)   9248        activation_187[0][0]
# __________________________________________________________________________________________________
# conv2d-2c-branch1b_split4 (Conv (None, 28, 28, 32)   9248        activation_189[0][0]
# __________________________________________________________________________________________________
# batchnorm-2c-branch1b_split1 (B (None, 28, 28, 32)   128         conv2d-2c-branch1b_split1[0][0]
# __________________________________________________________________________________________________
# batchnorm-2c-branch1b_split2 (B (None, 28, 28, 32)   128         conv2d-2c-branch1b_split2[0][0]
# __________________________________________________________________________________________________
# batchnorm-2c-branch1b_split3 (B (None, 28, 28, 32)   128         conv2d-2c-branch1b_split3[0][0]
# __________________________________________________________________________________________________
# batchnorm-2c-branch1b_split4 (B (None, 28, 28, 32)   128         conv2d-2c-branch1b_split4[0][0]
# __________________________________________________________________________________________________
# activation_184 (Activation)     (None, 28, 28, 32)   0           batchnorm-2c-branch1b_split1[0][0
# __________________________________________________________________________________________________
# activation_186 (Activation)     (None, 28, 28, 32)   0           batchnorm-2c-branch1b_split2[0][0
# __________________________________________________________________________________________________
# activation_188 (Activation)     (None, 28, 28, 32)   0           batchnorm-2c-branch1b_split3[0][0
# __________________________________________________________________________________________________
# activation_190 (Activation)     (None, 28, 28, 32)   0           batchnorm-2c-branch1b_split4[0][0
# __________________________________________________________________________________________________
# concat2c (Concatenate)          (None, 28, 28, 128)  0           activation_184[0][0]
#                                                                  activation_186[0][0]
#                                                                  activation_188[0][0]
#                                                                  activation_190[0][0]
# __________________________________________________________________________________________________
# conv2d-trans2c (Conv2D)         (None, 28, 28, 256)  33024       concat2c[0][0]
# __________________________________________________________________________________________________
# batchnorm-trans2c (BatchNormali (None, 28, 28, 256)  1024        conv2d-trans2c[0][0]
# __________________________________________________________________________________________________
# activation_191 (Activation)     (None, 28, 28, 256)  0           batchnorm-trans2c[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 28, 28, 256)  0           activation_191[0][0]
#                                                                  activation_182[0][0]
# __________________________________________________________________________________________________
# activation_192 (Activation)     (None, 28, 28, 256)  0           add_19[0][0]
# __________________________________________________________________________________________________
# lambda_77 (Lambda)              (None, 28, 28, 64)   0           activation_192[0][0]
# __________________________________________________________________________________________________
# lambda_78 (Lambda)              (None, 28, 28, 64)   0           activation_192[0][0]
# __________________________________________________________________________________________________
# lambda_79 (Lambda)              (None, 28, 28, 64)   0           activation_192[0][0]
# __________________________________________________________________________________________________
# lambda_80 (Lambda)              (None, 28, 28, 64)   0           activation_192[0][0]
# __________________________________________________________________________________________________
# conv2d-3a-branch1a_split1 (Conv (None, 14, 14, 64)   4160        lambda_77[0][0]
# __________________________________________________________________________________________________
# conv2d-3a-branch1a_split2 (Conv (None, 14, 14, 64)   4160        lambda_78[0][0]
# __________________________________________________________________________________________________
# conv2d-3a-branch1a_split3 (Conv (None, 14, 14, 64)   4160        lambda_79[0][0]
# __________________________________________________________________________________________________
# conv2d-3a-branch1a_split4 (Conv (None, 14, 14, 64)   4160        lambda_80[0][0]
# __________________________________________________________________________________________________
# batchnorm-3a-branch1a_split1 (B (None, 14, 14, 64)   256         conv2d-3a-branch1a_split1[0][0]
# __________________________________________________________________________________________________
# batchnorm-3a-branch1a_split2 (B (None, 14, 14, 64)   256         conv2d-3a-branch1a_split2[0][0]
# __________________________________________________________________________________________________
# batchnorm-3a-branch1a_split3 (B (None, 14, 14, 64)   256         conv2d-3a-branch1a_split3[0][0]
# __________________________________________________________________________________________________
# batchnorm-3a-branch1a_split4 (B (None, 14, 14, 64)   256         conv2d-3a-branch1a_split4[0][0]
# __________________________________________________________________________________________________
# activation_193 (Activation)     (None, 14, 14, 64)   0           batchnorm-3a-branch1a_split1[0][0
# __________________________________________________________________________________________________
# activation_195 (Activation)     (None, 14, 14, 64)   0           batchnorm-3a-branch1a_split2[0][0
# __________________________________________________________________________________________________
# activation_197 (Activation)     (None, 14, 14, 64)   0           batchnorm-3a-branch1a_split3[0][0
# __________________________________________________________________________________________________
# activation_199 (Activation)     (None, 14, 14, 64)   0           batchnorm-3a-branch1a_split4[0][0
# __________________________________________________________________________________________________
# conv2d-3a-branch1b_split1 (Conv (None, 14, 14, 64)   36928       activation_193[0][0]
# __________________________________________________________________________________________________
# conv2d-3a-branch1b_split2 (Conv (None, 14, 14, 64)   36928       activation_195[0][0]
# __________________________________________________________________________________________________
# conv2d-3a-branch1b_split3 (Conv (None, 14, 14, 64)   36928       activation_197[0][0]
# __________________________________________________________________________________________________
# conv2d-3a-branch1b_split4 (Conv (None, 14, 14, 64)   36928       activation_199[0][0]
# __________________________________________________________________________________________________
# batchnorm-3a-branch1b_split1 (B (None, 14, 14, 64)   256         conv2d-3a-branch1b_split1[0][0]
# __________________________________________________________________________________________________
# batchnorm-3a-branch1b_split2 (B (None, 14, 14, 64)   256         conv2d-3a-branch1b_split2[0][0]
# __________________________________________________________________________________________________
# batchnorm-3a-branch1b_split3 (B (None, 14, 14, 64)   256         conv2d-3a-branch1b_split3[0][0]
# __________________________________________________________________________________________________
# batchnorm-3a-branch1b_split4 (B (None, 14, 14, 64)   256         conv2d-3a-branch1b_split4[0][0]
# __________________________________________________________________________________________________
# activation_194 (Activation)     (None, 14, 14, 64)   0           batchnorm-3a-branch1b_split1[0][0
# __________________________________________________________________________________________________
# activation_196 (Activation)     (None, 14, 14, 64)   0           batchnorm-3a-branch1b_split2[0][0
# __________________________________________________________________________________________________
# activation_198 (Activation)     (None, 14, 14, 64)   0           batchnorm-3a-branch1b_split3[0][0
# __________________________________________________________________________________________________
# activation_200 (Activation)     (None, 14, 14, 64)   0           batchnorm-3a-branch1b_split4[0][0
# __________________________________________________________________________________________________
# concat3a (Concatenate)          (None, 14, 14, 256)  0           activation_194[0][0]
#                                                                  activation_196[0][0]
#                                                                  activation_198[0][0]
#                                                                  activation_200[0][0]
# __________________________________________________________________________________________________
# conv2d-trans3a (Conv2D)         (None, 14, 14, 512)  131584      concat3a[0][0]
# __________________________________________________________________________________________________
# batchnorm-trans3a (BatchNormali (None, 14, 14, 512)  2048        conv2d-trans3a[0][0]
# __________________________________________________________________________________________________
# conv2d-3a-branch2 (Conv2D)      (None, 14, 14, 512)  131584      activation_192[0][0]
# __________________________________________________________________________________________________
# activation_201 (Activation)     (None, 14, 14, 512)  0           batchnorm-trans3a[0][0]
# __________________________________________________________________________________________________
# batchnorm-3a-branch2 (BatchNorm (None, 14, 14, 512)  2048        conv2d-3a-branch2[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 14, 14, 512)  0           activation_201[0][0]
#                                                                  batchnorm-3a-branch2[0][0]
# __________________________________________________________________________________________________
# activation_202 (Activation)     (None, 14, 14, 512)  0           add_20[0][0]
# __________________________________________________________________________________________________
# lambda_81 (Lambda)              (None, 14, 14, 128)  0           activation_202[0][0]
# __________________________________________________________________________________________________
# lambda_82 (Lambda)              (None, 14, 14, 128)  0           activation_202[0][0]
# __________________________________________________________________________________________________
# lambda_83 (Lambda)              (None, 14, 14, 128)  0           activation_202[0][0]
# __________________________________________________________________________________________________
# lambda_84 (Lambda)              (None, 14, 14, 128)  0           activation_202[0][0]
# __________________________________________________________________________________________________
# conv2d-3b-branch1a_split1 (Conv (None, 14, 14, 64)   8256        lambda_81[0][0]
# __________________________________________________________________________________________________
# conv2d-3b-branch1a_split2 (Conv (None, 14, 14, 64)   8256        lambda_82[0][0]
# __________________________________________________________________________________________________
# conv2d-3b-branch1a_split3 (Conv (None, 14, 14, 64)   8256        lambda_83[0][0]
# __________________________________________________________________________________________________
# conv2d-3b-branch1a_split4 (Conv (None, 14, 14, 64)   8256        lambda_84[0][0]
# __________________________________________________________________________________________________
# batchnorm-3b-branch1a_split1 (B (None, 14, 14, 64)   256         conv2d-3b-branch1a_split1[0][0]
# __________________________________________________________________________________________________
# batchnorm-3b-branch1a_split2 (B (None, 14, 14, 64)   256         conv2d-3b-branch1a_split2[0][0]
# __________________________________________________________________________________________________
# batchnorm-3b-branch1a_split3 (B (None, 14, 14, 64)   256         conv2d-3b-branch1a_split3[0][0]
# __________________________________________________________________________________________________
# batchnorm-3b-branch1a_split4 (B (None, 14, 14, 64)   256         conv2d-3b-branch1a_split4[0][0]
# __________________________________________________________________________________________________
# activation_203 (Activation)     (None, 14, 14, 64)   0           batchnorm-3b-branch1a_split1[0][0
# __________________________________________________________________________________________________
# activation_205 (Activation)     (None, 14, 14, 64)   0           batchnorm-3b-branch1a_split2[0][0
# __________________________________________________________________________________________________
# activation_207 (Activation)     (None, 14, 14, 64)   0           batchnorm-3b-branch1a_split3[0][0
# __________________________________________________________________________________________________
# activation_209 (Activation)     (None, 14, 14, 64)   0           batchnorm-3b-branch1a_split4[0][0
# __________________________________________________________________________________________________
# conv2d-3b-branch1b_split1 (Conv (None, 14, 14, 64)   36928       activation_203[0][0]
# __________________________________________________________________________________________________
# conv2d-3b-branch1b_split2 (Conv (None, 14, 14, 64)   36928       activation_205[0][0]
# __________________________________________________________________________________________________
# conv2d-3b-branch1b_split3 (Conv (None, 14, 14, 64)   36928       activation_207[0][0]
# __________________________________________________________________________________________________
# conv2d-3b-branch1b_split4 (Conv (None, 14, 14, 64)   36928       activation_209[0][0]
# __________________________________________________________________________________________________
# batchnorm-3b-branch1b_split1 (B (None, 14, 14, 64)   256         conv2d-3b-branch1b_split1[0][0]
# __________________________________________________________________________________________________
# batchnorm-3b-branch1b_split2 (B (None, 14, 14, 64)   256         conv2d-3b-branch1b_split2[0][0]
# __________________________________________________________________________________________________
# batchnorm-3b-branch1b_split3 (B (None, 14, 14, 64)   256         conv2d-3b-branch1b_split3[0][0]
# __________________________________________________________________________________________________
# batchnorm-3b-branch1b_split4 (B (None, 14, 14, 64)   256         conv2d-3b-branch1b_split4[0][0]
# __________________________________________________________________________________________________
# activation_204 (Activation)     (None, 14, 14, 64)   0           batchnorm-3b-branch1b_split1[0][0
# __________________________________________________________________________________________________
# activation_206 (Activation)     (None, 14, 14, 64)   0           batchnorm-3b-branch1b_split2[0][0
# __________________________________________________________________________________________________
# activation_208 (Activation)     (None, 14, 14, 64)   0           batchnorm-3b-branch1b_split3[0][0
# __________________________________________________________________________________________________
# activation_210 (Activation)     (None, 14, 14, 64)   0           batchnorm-3b-branch1b_split4[0][0
# __________________________________________________________________________________________________
# concat3b (Concatenate)          (None, 14, 14, 256)  0           activation_204[0][0]
#                                                                  activation_206[0][0]
#                                                                  activation_208[0][0]
#                                                                  activation_210[0][0]
# __________________________________________________________________________________________________
# conv2d-trans3b (Conv2D)         (None, 14, 14, 512)  131584      concat3b[0][0]
# __________________________________________________________________________________________________
# batchnorm-trans3b (BatchNormali (None, 14, 14, 512)  2048        conv2d-trans3b[0][0]
# __________________________________________________________________________________________________
# activation_211 (Activation)     (None, 14, 14, 512)  0           batchnorm-trans3b[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 14, 14, 512)  0           activation_211[0][0]
#                                                                  activation_202[0][0]
# __________________________________________________________________________________________________
# activation_212 (Activation)     (None, 14, 14, 512)  0           add_21[0][0]
# __________________________________________________________________________________________________
# lambda_85 (Lambda)              (None, 14, 14, 128)  0           activation_212[0][0]
# __________________________________________________________________________________________________
# lambda_86 (Lambda)              (None, 14, 14, 128)  0           activation_212[0][0]
# __________________________________________________________________________________________________
# lambda_87 (Lambda)              (None, 14, 14, 128)  0           activation_212[0][0]
# __________________________________________________________________________________________________
# lambda_88 (Lambda)              (None, 14, 14, 128)  0           activation_212[0][0]
# __________________________________________________________________________________________________
# conv2d-3c-branch1a_split1 (Conv (None, 14, 14, 64)   8256        lambda_85[0][0]
# __________________________________________________________________________________________________
# conv2d-3c-branch1a_split2 (Conv (None, 14, 14, 64)   8256        lambda_86[0][0]
# __________________________________________________________________________________________________
# conv2d-3c-branch1a_split3 (Conv (None, 14, 14, 64)   8256        lambda_87[0][0]
# __________________________________________________________________________________________________
# conv2d-3c-branch1a_split4 (Conv (None, 14, 14, 64)   8256        lambda_88[0][0]
# __________________________________________________________________________________________________
# batchnorm-3c-branch1a_split1 (B (None, 14, 14, 64)   256         conv2d-3c-branch1a_split1[0][0]
# __________________________________________________________________________________________________
# batchnorm-3c-branch1a_split2 (B (None, 14, 14, 64)   256         conv2d-3c-branch1a_split2[0][0]
# __________________________________________________________________________________________________
# batchnorm-3c-branch1a_split3 (B (None, 14, 14, 64)   256         conv2d-3c-branch1a_split3[0][0]
# __________________________________________________________________________________________________
# batchnorm-3c-branch1a_split4 (B (None, 14, 14, 64)   256         conv2d-3c-branch1a_split4[0][0]
# __________________________________________________________________________________________________
# activation_213 (Activation)     (None, 14, 14, 64)   0           batchnorm-3c-branch1a_split1[0][0
# __________________________________________________________________________________________________
# activation_215 (Activation)     (None, 14, 14, 64)   0           batchnorm-3c-branch1a_split2[0][0
# __________________________________________________________________________________________________
# activation_217 (Activation)     (None, 14, 14, 64)   0           batchnorm-3c-branch1a_split3[0][0
# __________________________________________________________________________________________________
# activation_219 (Activation)     (None, 14, 14, 64)   0           batchnorm-3c-branch1a_split4[0][0
# __________________________________________________________________________________________________
# conv2d-3c-branch1b_split1 (Conv (None, 14, 14, 64)   36928       activation_213[0][0]
# __________________________________________________________________________________________________
# conv2d-3c-branch1b_split2 (Conv (None, 14, 14, 64)   36928       activation_215[0][0]
# __________________________________________________________________________________________________
# conv2d-3c-branch1b_split3 (Conv (None, 14, 14, 64)   36928       activation_217[0][0]
# __________________________________________________________________________________________________
# conv2d-3c-branch1b_split4 (Conv (None, 14, 14, 64)   36928       activation_219[0][0]
# __________________________________________________________________________________________________
# batchnorm-3c-branch1b_split1 (B (None, 14, 14, 64)   256         conv2d-3c-branch1b_split1[0][0]
# __________________________________________________________________________________________________
# batchnorm-3c-branch1b_split2 (B (None, 14, 14, 64)   256         conv2d-3c-branch1b_split2[0][0]
# __________________________________________________________________________________________________
# batchnorm-3c-branch1b_split3 (B (None, 14, 14, 64)   256         conv2d-3c-branch1b_split3[0][0]
# __________________________________________________________________________________________________
# batchnorm-3c-branch1b_split4 (B (None, 14, 14, 64)   256         conv2d-3c-branch1b_split4[0][0]
# __________________________________________________________________________________________________
# activation_214 (Activation)     (None, 14, 14, 64)   0           batchnorm-3c-branch1b_split1[0][0
# __________________________________________________________________________________________________
# activation_216 (Activation)     (None, 14, 14, 64)   0           batchnorm-3c-branch1b_split2[0][0
# __________________________________________________________________________________________________
# activation_218 (Activation)     (None, 14, 14, 64)   0           batchnorm-3c-branch1b_split3[0][0
# __________________________________________________________________________________________________
# activation_220 (Activation)     (None, 14, 14, 64)   0           batchnorm-3c-branch1b_split4[0][0
# __________________________________________________________________________________________________
# concat3c (Concatenate)          (None, 14, 14, 256)  0           activation_214[0][0]
#                                                                  activation_216[0][0]
#                                                                  activation_218[0][0]
#                                                                  activation_220[0][0]
# __________________________________________________________________________________________________
# conv2d-trans3c (Conv2D)         (None, 14, 14, 512)  131584      concat3c[0][0]
# __________________________________________________________________________________________________
# batchnorm-trans3c (BatchNormali (None, 14, 14, 512)  2048        conv2d-trans3c[0][0]
# __________________________________________________________________________________________________
# activation_221 (Activation)     (None, 14, 14, 512)  0           batchnorm-trans3c[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 14, 14, 512)  0           activation_221[0][0]
#                                                                  activation_212[0][0]
# __________________________________________________________________________________________________
# activation_222 (Activation)     (None, 14, 14, 512)  0           add_22[0][0]
# __________________________________________________________________________________________________
# lambda_89 (Lambda)              (None, 14, 14, 128)  0           activation_222[0][0]
# __________________________________________________________________________________________________
# lambda_90 (Lambda)              (None, 14, 14, 128)  0           activation_222[0][0]
# __________________________________________________________________________________________________
# lambda_91 (Lambda)              (None, 14, 14, 128)  0           activation_222[0][0]
# __________________________________________________________________________________________________
# lambda_92 (Lambda)              (None, 14, 14, 128)  0           activation_222[0][0]
# __________________________________________________________________________________________________
# conv2d-3d-branch1a_split1 (Conv (None, 14, 14, 64)   8256        lambda_89[0][0]
# __________________________________________________________________________________________________
# conv2d-3d-branch1a_split2 (Conv (None, 14, 14, 64)   8256        lambda_90[0][0]
# __________________________________________________________________________________________________
# conv2d-3d-branch1a_split3 (Conv (None, 14, 14, 64)   8256        lambda_91[0][0]
# __________________________________________________________________________________________________
# conv2d-3d-branch1a_split4 (Conv (None, 14, 14, 64)   8256        lambda_92[0][0]
# __________________________________________________________________________________________________
# batchnorm-3d-branch1a_split1 (B (None, 14, 14, 64)   256         conv2d-3d-branch1a_split1[0][0]
# __________________________________________________________________________________________________
# batchnorm-3d-branch1a_split2 (B (None, 14, 14, 64)   256         conv2d-3d-branch1a_split2[0][0]
# __________________________________________________________________________________________________
# batchnorm-3d-branch1a_split3 (B (None, 14, 14, 64)   256         conv2d-3d-branch1a_split3[0][0]
# __________________________________________________________________________________________________
# batchnorm-3d-branch1a_split4 (B (None, 14, 14, 64)   256         conv2d-3d-branch1a_split4[0][0]
# __________________________________________________________________________________________________
# activation_223 (Activation)     (None, 14, 14, 64)   0           batchnorm-3d-branch1a_split1[0][0
# __________________________________________________________________________________________________
# activation_225 (Activation)     (None, 14, 14, 64)   0           batchnorm-3d-branch1a_split2[0][0
# __________________________________________________________________________________________________
# activation_227 (Activation)     (None, 14, 14, 64)   0           batchnorm-3d-branch1a_split3[0][0
# ...
# activation_301 (Activation)     (None, 4, 4, 2048)   0           batchnorm-trans5a[0][0]
# __________________________________________________________________________________________________
# batchnorm-5a-branch2 (BatchNorm (None, 4, 4, 2048)   8192        conv2d-5a-branch2[0][0]
# __________________________________________________________________________________________________
# add_30 (Add)                    (None, 4, 4, 2048)   0           activation_301[0][0]
#                                                                  batchnorm-5a-branch2[0][0]
# __________________________________________________________________________________________________
# activation_302 (Activation)     (None, 4, 4, 2048)   0           add_30[0][0]
# __________________________________________________________________________________________________
# lambda_121 (Lambda)             (None, 4, 4, 512)    0           activation_302[0][0]
# __________________________________________________________________________________________________
# lambda_122 (Lambda)             (None, 4, 4, 512)    0           activation_302[0][0]
# __________________________________________________________________________________________________
# lambda_123 (Lambda)             (None, 4, 4, 512)    0           activation_302[0][0]
# __________________________________________________________________________________________________
# lambda_124 (Lambda)             (None, 4, 4, 512)    0           activation_302[0][0]
# __________________________________________________________________________________________________
# conv2d-5b-branch1a_split1 (Conv (None, 4, 4, 256)    131328      lambda_121[0][0]
# __________________________________________________________________________________________________
# conv2d-5b-branch1a_split2 (Conv (None, 4, 4, 256)    131328      lambda_122[0][0]
# __________________________________________________________________________________________________
# conv2d-5b-branch1a_split3 (Conv (None, 4, 4, 256)    131328      lambda_123[0][0]
# __________________________________________________________________________________________________
# conv2d-5b-branch1a_split4 (Conv (None, 4, 4, 256)    131328      lambda_124[0][0]
# __________________________________________________________________________________________________
# batchnorm-5b-branch1a_split1 (B (None, 4, 4, 256)    1024        conv2d-5b-branch1a_split1[0][0]
# __________________________________________________________________________________________________
# batchnorm-5b-branch1a_split2 (B (None, 4, 4, 256)    1024        conv2d-5b-branch1a_split2[0][0]
# __________________________________________________________________________________________________
# batchnorm-5b-branch1a_split3 (B (None, 4, 4, 256)    1024        conv2d-5b-branch1a_split3[0][0]
# __________________________________________________________________________________________________
# batchnorm-5b-branch1a_split4 (B (None, 4, 4, 256)    1024        conv2d-5b-branch1a_split4[0][0]
# __________________________________________________________________________________________________
# activation_303 (Activation)     (None, 4, 4, 256)    0           batchnorm-5b-branch1a_split1[0][0
# __________________________________________________________________________________________________
# activation_305 (Activation)     (None, 4, 4, 256)    0           batchnorm-5b-branch1a_split2[0][0
# __________________________________________________________________________________________________
# activation_307 (Activation)     (None, 4, 4, 256)    0           batchnorm-5b-branch1a_split3[0][0
# __________________________________________________________________________________________________
# activation_309 (Activation)     (None, 4, 4, 256)    0           batchnorm-5b-branch1a_split4[0][0
# __________________________________________________________________________________________________
# conv2d-5b-branch1b_split1 (Conv (None, 4, 4, 256)    590080      activation_303[0][0]
# __________________________________________________________________________________________________
# conv2d-5b-branch1b_split2 (Conv (None, 4, 4, 256)    590080      activation_305[0][0]
# __________________________________________________________________________________________________
# conv2d-5b-branch1b_split3 (Conv (None, 4, 4, 256)    590080      activation_307[0][0]
# __________________________________________________________________________________________________
# conv2d-5b-branch1b_split4 (Conv (None, 4, 4, 256)    590080      activation_309[0][0]
# __________________________________________________________________________________________________
# batchnorm-5b-branch1b_split1 (B (None, 4, 4, 256)    1024        conv2d-5b-branch1b_split1[0][0]
# __________________________________________________________________________________________________
# batchnorm-5b-branch1b_split2 (B (None, 4, 4, 256)    1024        conv2d-5b-branch1b_split2[0][0]
# __________________________________________________________________________________________________
# batchnorm-5b-branch1b_split3 (B (None, 4, 4, 256)    1024        conv2d-5b-branch1b_split3[0][0]
# __________________________________________________________________________________________________
# batchnorm-5b-branch1b_split4 (B (None, 4, 4, 256)    1024        conv2d-5b-branch1b_split4[0][0]
# __________________________________________________________________________________________________
# activation_304 (Activation)     (None, 4, 4, 256)    0           batchnorm-5b-branch1b_split1[0][0
# __________________________________________________________________________________________________
# activation_306 (Activation)     (None, 4, 4, 256)    0           batchnorm-5b-branch1b_split2[0][0
# __________________________________________________________________________________________________
# activation_308 (Activation)     (None, 4, 4, 256)    0           batchnorm-5b-branch1b_split3[0][0
# __________________________________________________________________________________________________
# activation_310 (Activation)     (None, 4, 4, 256)    0           batchnorm-5b-branch1b_split4[0][0
# __________________________________________________________________________________________________
# concat5b (Concatenate)          (None, 4, 4, 1024)   0           activation_304[0][0]
#                                                                  activation_306[0][0]
#                                                                  activation_308[0][0]
#                                                                  activation_310[0][0]
# __________________________________________________________________________________________________
# conv2d-trans5b (Conv2D)         (None, 4, 4, 2048)   2099200     concat5b[0][0]
# __________________________________________________________________________________________________
# batchnorm-trans5b (BatchNormali (None, 4, 4, 2048)   8192        conv2d-trans5b[0][0]
# __________________________________________________________________________________________________
# activation_311 (Activation)     (None, 4, 4, 2048)   0           batchnorm-trans5b[0][0]
# __________________________________________________________________________________________________
# add_31 (Add)                    (None, 4, 4, 2048)   0           activation_311[0][0]
#                                                                  activation_302[0][0]
# __________________________________________________________________________________________________
# activation_312 (Activation)     (None, 4, 4, 2048)   0           add_31[0][0]
# __________________________________________________________________________________________________
# lambda_125 (Lambda)             (None, 4, 4, 512)    0           activation_312[0][0]
# __________________________________________________________________________________________________
# lambda_126 (Lambda)             (None, 4, 4, 512)    0           activation_312[0][0]
# __________________________________________________________________________________________________
# lambda_127 (Lambda)             (None, 4, 4, 512)    0           activation_312[0][0]
# __________________________________________________________________________________________________
# lambda_128 (Lambda)             (None, 4, 4, 512)    0           activation_312[0][0]
# __________________________________________________________________________________________________
# conv2d-5c-branch1a_split1 (Conv (None, 4, 4, 256)    131328      lambda_125[0][0]
# __________________________________________________________________________________________________
# conv2d-5c-branch1a_split2 (Conv (None, 4, 4, 256)    131328      lambda_126[0][0]
# __________________________________________________________________________________________________
# conv2d-5c-branch1a_split3 (Conv (None, 4, 4, 256)    131328      lambda_127[0][0]
# __________________________________________________________________________________________________
# conv2d-5c-branch1a_split4 (Conv (None, 4, 4, 256)    131328      lambda_128[0][0]
# __________________________________________________________________________________________________
# batchnorm-5c-branch1a_split1 (B (None, 4, 4, 256)    1024        conv2d-5c-branch1a_split1[0][0]
# __________________________________________________________________________________________________
# batchnorm-5c-branch1a_split2 (B (None, 4, 4, 256)    1024        conv2d-5c-branch1a_split2[0][0]
# __________________________________________________________________________________________________
# batchnorm-5c-branch1a_split3 (B (None, 4, 4, 256)    1024        conv2d-5c-branch1a_split3[0][0]
# __________________________________________________________________________________________________
# batchnorm-5c-branch1a_split4 (B (None, 4, 4, 256)    1024        conv2d-5c-branch1a_split4[0][0]
# __________________________________________________________________________________________________
# activation_313 (Activation)     (None, 4, 4, 256)    0           batchnorm-5c-branch1a_split1[0][0
# __________________________________________________________________________________________________
# activation_315 (Activation)     (None, 4, 4, 256)    0           batchnorm-5c-branch1a_split2[0][0
# __________________________________________________________________________________________________
# activation_317 (Activation)     (None, 4, 4, 256)    0           batchnorm-5c-branch1a_split3[0][0
# __________________________________________________________________________________________________
# activation_319 (Activation)     (None, 4, 4, 256)    0           batchnorm-5c-branch1a_split4[0][0
# __________________________________________________________________________________________________
# conv2d-5c-branch1b_split1 (Conv (None, 4, 4, 256)    590080      activation_313[0][0]
# __________________________________________________________________________________________________
# conv2d-5c-branch1b_split2 (Conv (None, 4, 4, 256)    590080      activation_315[0][0]
# __________________________________________________________________________________________________
# conv2d-5c-branch1b_split3 (Conv (None, 4, 4, 256)    590080      activation_317[0][0]
# __________________________________________________________________________________________________
# conv2d-5c-branch1b_split4 (Conv (None, 4, 4, 256)    590080      activation_319[0][0]
# __________________________________________________________________________________________________
# batchnorm-5c-branch1b_split1 (B (None, 4, 4, 256)    1024        conv2d-5c-branch1b_split1[0][0]
# __________________________________________________________________________________________________
# batchnorm-5c-branch1b_split2 (B (None, 4, 4, 256)    1024        conv2d-5c-branch1b_split2[0][0]
# __________________________________________________________________________________________________
# batchnorm-5c-branch1b_split3 (B (None, 4, 4, 256)    1024        conv2d-5c-branch1b_split3[0][0]
# __________________________________________________________________________________________________
# batchnorm-5c-branch1b_split4 (B (None, 4, 4, 256)    1024        conv2d-5c-branch1b_split4[0][0]
# __________________________________________________________________________________________________
# activation_314 (Activation)     (None, 4, 4, 256)    0           batchnorm-5c-branch1b_split1[0][0
# __________________________________________________________________________________________________
# activation_316 (Activation)     (None, 4, 4, 256)    0           batchnorm-5c-branch1b_split2[0][0
# __________________________________________________________________________________________________
# activation_318 (Activation)     (None, 4, 4, 256)    0           batchnorm-5c-branch1b_split3[0][0
# __________________________________________________________________________________________________
# activation_320 (Activation)     (None, 4, 4, 256)    0           batchnorm-5c-branch1b_split4[0][0
# __________________________________________________________________________________________________
# concat5c (Concatenate)          (None, 4, 4, 1024)   0           activation_314[0][0]
#                                                                  activation_316[0][0]
#                                                                  activation_318[0][0]
#                                                                  activation_320[0][0]
# __________________________________________________________________________________________________
# conv2d-trans5c (Conv2D)         (None, 4, 4, 2048)   2099200     concat5c[0][0]
# __________________________________________________________________________________________________
# batchnorm-trans5c (BatchNormali (None, 4, 4, 2048)   8192        conv2d-trans5c[0][0]
# __________________________________________________________________________________________________
# activation_321 (Activation)     (None, 4, 4, 2048)   0           batchnorm-trans5c[0][0]
# __________________________________________________________________________________________________
# add_32 (Add)                    (None, 4, 4, 2048)   0           activation_321[0][0]
#                                                                  activation_312[0][0]
# __________________________________________________________________________________________________
# activation_322 (Activation)     (None, 4, 4, 2048)   0           add_32[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 2, 2, 2048)   0           activation_322[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 8192)         0           average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# fc2 (Dense)                     (None, 2)            16386       flatten_2[0][0]
# ==================================================================================================
# Total params: 26,507,010
# Trainable params: 26,438,786
# Non-trainable params: 68,224
# __________________________________________________________________________________________________

# %%
# Train
resnext50.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_test, y_test), callbacks=callbacks)
